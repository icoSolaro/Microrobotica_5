# %%
import numpy as np

# %% [markdown]
# ### Es 11 pag 107
# Sul territorio comunale...

# %%
ERRORE_SCONOSCIUTO=0.001
FALLIMENTO=0.002
N_ORE=24
MISURAZIONI_P_H=60
N_CENTRALINE=3

MEDIO=19
VARIANZA=5
matrix = np.random.normal(MEDIO, np.sqrt(VARIANZA), (N_ORE*MISURAZIONI_P_H, N_CENTRALINE))
matrix [np.random.random(matrix.shape)<FALLIMENTO]=9999.9
matrix [np.random.random(matrix.shape)<ERRORE_SCONOSCIUTO]=-1
matrix
# Out:
# array([[19.27033935, 19.95466855, 22.3096233 ],
#        [18.33858338, 19.8791484 , 17.13116767],
#        [19.70678093, 17.52166841, 19.78354598],
#        ...,
#        [18.00159675, 19.0082628 , 17.94929392],
#        [20.30689113, 21.39896401, 20.97138959],
#        [16.93865132, 19.56442648, 16.38553235]])

# %%
error9=matrix==9999.9
error1=matrix==-1
error=error1 | error9
error
# Out:
# array([[False, False, False],
#        [False, False, False],
#        [False, False, False],
#        ...,
#        [False, False, False],
#        [False, False, False],
#        [False, False, False]])

# %%
np.count_nonzero(np.any(error, axis=1))
# Out:
# 13

# %%
matrix_clean=matrix[np.logical_not(np.any(error, axis=1))].copy
# Out:
# array([[19.27033935, 19.95466855, 22.3096233 ],
#        [18.33858338, 19.8791484 , 17.13116767],
#        [19.70678093, 17.52166841, 19.78354598],
#        ...,
#        [18.00159675, 19.0082628 , 17.94929392],
#        [20.30689113, 21.39896401, 20.97138959],
#        [16.93865132, 19.56442648, 16.38553235]])

# %%
matrixModificata9=matrix!=9999.9# & matrix!=9999.9
matrix=matrix[matrixModificata9[]]

# %%
np.isclose?
# Out:
# Signature:       np.isclose(a, b, rtol=1e-05, atol=1e-08, equal_nan=False)
# Call signature:  np.isclose(*args, **kwargs)
# Type:            _ArrayFunctionDispatcher
# String form:     <function isclose at 0x000001B42DB0E980>
# File:            c:\program files\anaconda\lib\site-packages\numpy\core\numeric.py
# Docstring:
# Returns a boolean array where two arrays are element-wise equal within a
# tolerance.
#
# The tolerance values are positive, typically very small numbers.  The
# relative difference (`rtol` * abs(`b`)) and the absolute difference
# `atol` are added together to compare against the absolute difference
# between `a` and `b`.
#
# .. warning:: The default `atol` is not appropriate for comparing numbers
#              that are much smaller than one (see Notes).
#
# Parameters
# ----------
# a, b : array_like
#     Input arrays to compare.
# rtol : float
#     The relative tolerance parameter (see Notes).
# atol : float
# ...
